# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
fifa=pd.read_csv('players_20.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, CF, ST
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 2          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 3          E. Hazard                          Eden Hazard           LW, CF
# 4       K. De Bruyne                      Kevin De Bruyne          CAM, CM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
fifa.shape
# Out:
# (18483, 110)

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# player_positions
# overall
# potential
# value_eur
# wage_eur
# age
# dob
# height_cm
# weight_kg
# club_team_id
# club_name
# league_name
# league_level
# club_position
# club_jersey_number
# club_loaned_from
# club_joined
# club_contract_valid_until
# nationality_id
# nationality_name
# nation_team_id
# nation_position
# nation_jersey_number
# preferred_foot
# weak_foot
# skill_moves
# international_reputation
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# player_traits
# pace
# shooting
# passing
# dribbling
# defending
# physic
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# ...

# %%
#checking players no. according to there nationality

# %%
fifa['nationality_name'].value_counts()
# Out:
# England        1670
# Germany        1218
# Spain          1045
# France         1004
# Argentina       886
#                ...
# Puerto Rico       1
# Eritrea           1
# Bahrain           1
# Chad              1
# Indonesia         1
# Name: nationality_name, Length: 162, dtype: int64

# %%
fifa['nationality_name'].value_counts()[0:10]
# Out:
# England        1670
# Germany        1218
# Spain          1045
# France         1004
# Argentina       886
# Brazil          827
# Italy           732
# Colombia        612
# Japan           479
# Netherlands     416
# Name: nationality_name, dtype: int64

# %%
fifa['nationality_name'].value_counts()[0:5]
# Out:
# England      1670
# Germany      1218
# Spain        1045
# France       1004
# Argentina     886
# Name: nationality_name, dtype: int64

# %%
#making bar plot according to nationality of top 5

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality_name'].value_counts()[0:5].keys()),list(fifa['nationality_name'].value_counts()[0:5]),color='g')
plt.show()

# %%
pl_salary= fifa[['short_name','wage_eur']]

# %%
pl_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi  560000.0
# 1  Cristiano Ronaldo  410000.0
# 2          Neymar Jr  290000.0
# 3          E. Hazard  470000.0
# 4       K. De Bruyne  370000.0

# %%
#now we sort the salary values in descending

# %%
pl_salary = pl_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
pl_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi  560000.0
# 3           E. Hazard  470000.0
# 1   Cristiano Ronaldo  410000.0
# 4        K. De Bruyne  370000.0
# 17       A. Griezmann  370000.0

# %%
#now bar plot according to salary

# %%
plt.figure(figsize=(8,5))
plt.bar(list(pl_salary['short_name'])[0:5],list(pl_salary['wage_eur'])[0:5],color="pink")
# Out:
# <BarContainer object of 5 artists>

# %%
#now we analyzing GERMANY

# %%
germany = fifa[fifa['nationality_name']== 'Germany']
germany.head()
# Out:
#     sofifa_id                                         player_url  \
# 7      192448  https://sofifa.com/player/192448/marc-andre-te...
# 25     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 30     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 31     188350  https://sofifa.com/player/188350/marco-reus/20...
# 45     178603  https://sofifa.com/player/178603/mats-hummels/...
#
#        short_name              long_name player_positions  overall  potential  \
# 7   M. ter Stegen  Marc-André ter Stegen               GK       90         93
# 25       M. Neuer     Manuel Peter Neuer               GK       88         88
# 30       T. Kroos             Toni Kroos               CM       88         88
# 31        M. Reus             Marco Reus      CAM, LM, ST       88         88
# 45     M. Hummels           Mats Hummels               CB       87         87
#
#      value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
germany.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 8550      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1094      200212  https://sofifa.com/player/200212/michael-esser...
# 1411      199833  https://sofifa.com/player/199833/lars-unnersta...
# 16208     240218  https://sofifa.com/player/240218/alexander-wei...
# 13736     239746  https://sofifa.com/player/239746/lukas-watkowi...
#
#           short_name            long_name player_positions  overall  \
# 8550       A. Seydel         Aaron Seydel           ST, LM       67
# 1094        M. Esser        Michael Esser               GK       77
# 1411   L. Unnerstall      Lars Unnerstall               GK       76
# 16208   A. Weidinger  Alexander Weidinger               GK       58
# 13736   L. Watkowiak      Lukas Watkowiak               GK       62
#
#        potential  value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
germany.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 1411      199833  https://sofifa.com/player/199833/lars-unnersta...
# 13736     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 443       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1094      200212  https://sofifa.com/player/200212/michael-esser...
# 13775     241388  https://sofifa.com/player/241388/dennis-smarsc...
#
#           short_name                long_name player_positions  overall  \
# 1411   L. Unnerstall          Lars Unnerstall               GK       76
# 13736   L. Watkowiak          Lukas Watkowiak               GK       62
# 443      R. Fährmann  Ralf Sebastian Fährmann               GK       80
# 1094        M. Esser            Michael Esser               GK       77
# 13775     D. Smarsch           Dennis Smarsch               GK       62
#
#        potential   value_eur  wage_eur  age  ...   lcb    cb   rcb    rb  \
# ...

# %%
germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#         short_name  wage_eur
# 30        T. Kroos  330000.0
# 7    M. ter Stegen  250000.0
# 71         L. Sané  195000.0
# 126    İ. Gündoğan  180000.0
# 31         M. Reus  165000.0

# %%
#making bar plot of germany's top  5 player acc. to wage

# %%
plt.figure(figsize=(7,5))
plt.barh(list(germany['short_name'])[0:5],list(germany['wage_eur'])[0:5],color="r")
# Out:
# <BarContainer object of 5 artists>

# %%
#analyzation on shooting skills

# %%
pl_shoot = fifa[['short_name','shooting']]

# %%
pl_shoot.sort_values(by=['shooting'],ascending=False).head()
# Out:
#            short_name  shooting
# 1   Cristiano Ronaldo      93.0
# 0            L. Messi      92.0
# 19            H. Kane      91.0
# 11          S. Agüero      90.0
# 13          L. Suárez      89.0

# %%
pl_def= fifa[['short_name','defending','club_name','wage_eur']]

# %%
pl_def.head()
# Out:
#           short_name  defending            club_name  wage_eur
# 0           L. Messi       39.0         FC Barcelona  560000.0
# 1  Cristiano Ronaldo       35.0             Juventus  410000.0
# 2          Neymar Jr       32.0  Paris Saint-Germain  290000.0
# 3          E. Hazard       35.0       Real Madrid CF  470000.0
# 4       K. De Bruyne       61.0      Manchester City  370000.0

# %%
pl_def.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending          club_name  wage_eur
# 10  G. Chiellini       90.0           Juventus  210000.0
# 8    V. van Dijk       90.0          Liverpool  200000.0
# 29      D. Godín       89.0              Inter  135000.0
# 45    M. Hummels       89.0  Borussia Dortmund  125000.0
# 18  K. Koulibaly       89.0             Napoli  145000.0

# %%
#now analyzing real_madrid club

# %%
lp = fifa[fifa['club_name']=='Liverpool']

# %%
lp.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 9      209331  https://sofifa.com/player/209331/mohamed-salah...
# 37     208722  https://sofifa.com/player/208722/sadio-mane/20...
# 8      203376  https://sofifa.com/player/203376/virgil-van-di...
# 67     201942  https://sofifa.com/player/201942/roberto-firmi...
# 20     212831  https://sofifa.com/player/212831/alisson-ramse...
#
#          short_name                            long_name player_positions  \
# 9          M. Salah                  Mohamed Salah Ghaly           RW, ST
# 37          S. Mané                           Sadio Mané           LW, LM
# 8       V. van Dijk                      Virgil van Dijk               CB
# 67  Roberto Firmino  Roberto Firmino Barbosa de Oliveira      CF, ST, CAM
# 20          Alisson                Alisson Ramsés Becker               GK
#
#     overall  potential   value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
lp.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 9       209331  https://sofifa.com/player/209331/mohamed-salah...
# 37      208722  https://sofifa.com/player/208722/sadio-mane/20...
# 67      201942  https://sofifa.com/player/201942/roberto-firmi...
# 270     193348  https://sofifa.com/player/193348/xherdan-shaqi...
# 917     213135  https://sofifa.com/player/213135/divock-origi/...
#
#           short_name                            long_name player_positions  \
# 9           M. Salah                  Mohamed Salah Ghaly           RW, ST
# 37           S. Mané                           Sadio Mané           LW, LM
# 67   Roberto Firmino  Roberto Firmino Barbosa de Oliveira      CF, ST, CAM
# 270       X. Shaqiri                      Xherdan Shaqiri           RW, RM
# 917         D. Origi                   Divock Okoth Origi               ST
#
#      overall  potential   value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
lp.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 8       203376  https://sofifa.com/player/203376/virgil-van-di...
# 97      209499  https://sofifa.com/player/209499/fabio-henriqu...
# 274     197061  https://sofifa.com/player/197061/joel-matip/20...
# 100     216267  https://sofifa.com/player/216267/andrew-robert...
# 470     195086  https://sofifa.com/player/195086/dejan-lovren/...
#
#        short_name               long_name player_positions  overall  \
# 8     V. van Dijk         Virgil van Dijk               CB       90
# 97        Fabinho  Fábio Henrique Tavares              CDM       85
# 274      J. Matip    Joël Andre Job Matip               CB       82
# 100  A. Robertson        Andrew Robertson               LB       85
# 470     D. Lovren            Dejan Lovren               CB       80
#
#      potential   value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# 8           91  78000000.0  200000.0   27  ...  88+3  88+3  88+3  81+3  20+3
# ...

# %%
lp['nationality_name'].value_counts()
# Out:
# England                13
# Netherlands             4
# Brazil                  3
# Spain                   2
# Egypt                   1
# Senegal                 1
# Scotland                1
# Switzerland             1
# Cameroon                1
# Guinea                  1
# Croatia                 1
# Belgium                 1
# Germany                 1
# Republic of Ireland     1
# Algeria                 1
# Name: nationality_name, dtype: int64
